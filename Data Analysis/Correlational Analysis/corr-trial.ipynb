# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'input-std.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
print(data.head())

# Calculate correlation matrix
correlation_matrix = data[['MPA', 'FisheryConsumption', 'Share of global plastics emitted to ocean']].corr()
print("Correlation Matrix:\n", correlation_matrix)

# Plotting the correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# Scatter plot for MPA vs FisheryConsumption
plt.figure(figsize=(10, 6))
sns.scatterplot(x='MPA', y='FisheryConsumption', data=data)
plt.title('MPA vs Fishery Consumption')
plt.xlabel('MPA (%)')
plt.ylabel('Fishery Consumption')
plt.show()

# Scatter plot for MPA vs Share of global plastics emitted to ocean
plt.figure(figsize=(10, 6))
sns.scatterplot(x='MPA', y='Share of global plastics emitted to ocean', data=data)
plt.title('MPA vs Share of Global Plastics Emitted to Ocean')
plt.xlabel('MPA (%)')
plt.ylabel('Share of Global Plastics Emitted to Ocean')
plt.show()
# Out:
#         MPA  Share of global plastics emitted to ocean  FisheryConsumption  \
# 0 -0.552311                                  -0.189491           -0.150710
# 1 -0.392343                                  -0.168987           -0.202003
# 2  0.083552                                  -0.214095           -0.193999
# 3  0.111662                                  -0.094185           -0.094069
# 4 -0.542320                                  -0.214444           -0.203572
#
#    Country Name_Albania  Country Name_Algeria  Country Name_Angola  \
# 0             -0.087706             -0.087706            11.401754
# 1             11.401754             -0.087706            -0.087706
# 2             -0.087706             -0.087706            -0.087706
# 3             -0.087706             -0.087706            -0.087706
# 4             -0.087706             -0.087706            -0.087706
#
#    Country Name_Antigua and Barbuda  Country Name_Argentina  \
# ...
